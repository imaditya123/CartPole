# %% [markdown]
# # Import Packages

# %%
import os;
import gym;
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # Load Environment

# %%
environment_name ='CartPole-v1'
env=gym.make(environment_name)

# %%
environment_name
# Out:
# 'CartPole-v1'

# %%
episodes=5
for episode in range(1,episodes+1):
    state=env.reset()
    done=False
    score=0
    while not done:
        env.render()
        action=env.action_space.sample()
        n_state,reward,done,info=env.step(action)
        score+=reward
    print('Episode:{} Score{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score17.0
# Episode:2 Score17.0
# Episode:3 Score16.0
# Episode:4 Score10.0
# Episode:5 Score17.0

# %% [markdown]
# # Train Model

# %%
#make dir in path
log_path=os.path.join('Training','Logs')

# %%
log_path
# Out:
# 'Training/Logs'

# %%
env=gym.make(environment_name)
env=DummyVecEnv([lambda:env])
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_6
# -----------------------------
# | time/              |      |
# |    fps             | 858  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1357        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008344904 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00299    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 56          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1692        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010761363 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 31.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1929         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0074920347 |
# |    clip_fraction        | 0.0822       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0185      |
# |    value_loss           | 54           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2106         |
# |    iterations           | 5            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0064333784 |
# |    clip_fraction        | 0.0731       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0183      |
# |    value_loss           | 68.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2244        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008258854 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 55.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2354        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004843131 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 62.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2444        |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004903727 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.4         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00966    |
# |    value_loss           | 35.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2517       |
# |    iterations           | 9          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00568646 |
# |    clip_fraction        | 0.0352     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.567     |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.5       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00633   |
# |    value_loss           | 30.8       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2579         |
# |    iterations           | 10           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0073467726 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.578       |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.9          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00845     |
# |    value_loss           | 35.6         |
# ------------------------------------------

# %%
PPO_Path=os.path.join('Training','Saved Models','PPO_Model_CartPole')

# %%
model.save(PPO_Path)

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=True)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/tf_m1/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (500.0, 0.0)

# %% [markdown]
# # Testing

# %%
env.close()

# %%
episodes=5
for episode in range(1,episodes+1):
    obs=env.reset()
    done=False
    score=0
    while not done:
        env.render()
        action,_=model.predict(obs)
        n_state,reward,done,info=env.step(action)
        score+=reward
    print('Episode:{} Score{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score[15.]
# Episode:2 Score[22.]
# Episode:3 Score[15.]
# Episode:4 Score[10.]
# Episode:5 Score[21.]

# %% [markdown]
# # Viewing Logs in TensorBoard

# %%
training_log_path=os.path.join(log_path,'PPO_2')

# %%
training_log_path
# Out:
# 'Training/Logs/PPO_2'

# %% [markdown]
# Use this command in terminal
# $tensorboard --logdir=Training/Logs/PPO_2
# http://localhost:6006/

# %% [markdown]
# # Adding Callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback,StopTrainingOnRewardThreshold

# %%
save_path=os.path.join('Training','Saved Models')

# %%
stop_callback=StopTrainingOnRewardThreshold(reward_threshold=200,verbose=1)
eval_callback=EvalCallback(env,callback_on_new_best=stop_callback,
                          eval_freq=10000,
                          best_model_save_path=save_path,
                          verbose=1)

# %%
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_7
# -----------------------------
# | time/              |      |
# |    fps             | 6317 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4357        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008362288 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00139    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.48        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 52.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3940        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008472314 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0565      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 42.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3771        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009450957 |
# |    clip_fraction        | 0.0995      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 56.4        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=346.80 +/- 129.82
# Episode length: 346.80 +/- 129.82
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 347        |
# |    mean_reward          | 347        |
# | time/                   |            |
# |    total timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.00714169 |
# |    clip_fraction        | 0.0577     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.611     |
# |    explained_variance   | 0.304      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.8       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0143    |
# |    value_loss           | 61.6       |
# ----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 346.80  is above the threshold 200
# /opt/homebrew/Caskroom/miniforge/base/envs/tf_m1/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# # Changing Policies

# %%
net_arch=[dict(pi=[128,128,128,128],vf=[128,128,128,128])]

# %%
model=PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path,policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_8
# -----------------------------
# | time/              |      |
# |    fps             | 5134 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3035        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014861594 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.00236     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 18          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2659       |
# |    iterations           | 3          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01495949 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.648     |
# |    explained_variance   | 0.455      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.68       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0314    |
# |    value_loss           | 26.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2502       |
# |    iterations           | 4          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01139068 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.608     |
# |    explained_variance   | 0.367      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.4       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0273    |
# |    value_loss           | 45.7       |
# ----------------------------------------
# Eval num_timesteps=10000, episode_reward=300.60 +/- 72.06
# Episode length: 300.60 +/- 72.06
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 301         |
# |    mean_reward          | 301         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.010682878 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.38        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 35.9        |
# -----------------------------------------
# /opt/homebrew/Caskroom/miniforge/base/envs/tf_m1/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ------------------------------
# | time/              |       |
# |    fps             | 2304  |
# |    iterations      | 5     |
# |    time_elapsed    | 4     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2276        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008786695 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.5         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 18.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2255        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010262792 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.01        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 15.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2241        |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006225896 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.24        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 20.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2229       |
# |    iterations           | 9          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01462166 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.557     |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.93       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0181    |
# |    value_loss           | 8.38       |
# ----------------------------------------
# Eval num_timesteps=20000, episode_reward=485.20 +/- 29.60
# Episode length: 485.20 +/- 29.60
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 485       |
# |    mean_reward          | 485       |
# | time/                   |           |
# |    total timesteps      | 20000     |
# | train/                  |           |
# |    approx_kl            | 0.0099611 |
# |    clip_fraction        | 0.124     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.533    |
# |    explained_variance   | 0.904     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 18.4      |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.0112   |
# |    value_loss           | 24        |
# ---------------------------------------
# New best mean reward!
# Stopping training because the mean reward 485.20  is above the threshold 200

# %% [markdown]
# # Using Alternative Algorithm

# %%
from stable_baselines3 import DQN

# %%
model=DQN('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.964    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5810     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.921    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 7588     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 167      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.88     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 9151     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 252      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.821    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 11163    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 376      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.786    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 11851    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 451      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.755    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 12423    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 515      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.727    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 12795    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 575      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.671    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 13806    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 692      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.629    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 14323    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 780      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.597    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 14659    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 849      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.549    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 15276    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 949      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.5      |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 15938    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.458    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 16369    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.421    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 16791    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.385    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 17136    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.306    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 18159    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.269    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 18504    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.238    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 18753    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.199    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 19101    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1687     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.167    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 19341    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.135    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 19542    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.103    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 19731    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0533   |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 20185    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              |